# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafahmachado/SoulCode-PreparaTech/blob/main/Aula15bgq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Conectando dados ao ambiente em nuvem**

# %% [markdown]
# ## **Google Drive sem salvamento em pasta(dowload em máquina)**

# %%
# Passo 1: Precisamos fazer a abertura da biblioteca
from google.colab import files

# %%
# Passo 2: Fazendo o upload do nosso aarquivo
upload = files.upload()
# Out:
#      <input type="file" id="files-03b7e91e-4645-4acc-be06-659827c0bf97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03b7e91e-4645-4acc-be06-659827c0bf97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Passo 3: Abrindo a a biblioteca para EXTRAÇÃO do nosso dataset
import pandas as pd

# %%
# Passo 4: Extração da informação via pandas
df = pd.read_csv('/content/youtube_bruto.csv')   #passando de Dataset para Dataframe

# %%
# Passo 5: mostrando o  Dataframe
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Apple Pay Is Killing the Physical Wallet After...
# 1              1                    The most EXPENSIVE thing I own.
# 2              2                 My New House Gaming Setup is SICK!
# 3              3  Petrol Vs Liquid Nitrogen | Freezing Experimen...
# 4              4                     Best Back to School Tech 2022!
# ...          ...                                                ...
# 1876        1876                 Should You Learn Machine Learning?
# 1877        1877            Todos podemos aprender Machine learning
# 1878        1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879        1879                          What is Machine Learning?
# 1880        1880                   Don&#39;t learn machine learning
#
#          Video ID Published At           Keyword    Likes  Comments      Views
# ...

# %%
# Passo 6: Consideraremos que o tratamento foi realizado

# %%
# Passo 7: Exportação ao google Drive
df.to_csv('youtube_tratado.csv')

# %%
# Passo 8:Faça o dowload do seu arquivo tratado na sua máquina

# %%
# Passo 9:

# %% [markdown]
# ## Google Drive salvamento em pasta

# %%
# Passo 1: Comando de abertura para google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Passo 2: Abrindo a biblioteca para Extração do Dataset
import pandas as pd

# %%
# Passo 3:EXTRAÇÃO da informação via pandas
df = pd.read_csv('/content/drive/MyDrive/youtube/youtube_bruto.csv')

# %%
# Passo 4: Observando o dataframe
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Apple Pay Is Killing the Physical Wallet After...
# 1              1                    The most EXPENSIVE thing I own.
# 2              2                 My New House Gaming Setup is SICK!
# 3              3  Petrol Vs Liquid Nitrogen | Freezing Experimen...
# 4              4                     Best Back to School Tech 2022!
# ...          ...                                                ...
# 1876        1876                 Should You Learn Machine Learning?
# 1877        1877            Todos podemos aprender Machine learning
# 1878        1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879        1879                          What is Machine Learning?
# 1880        1880                   Don&#39;t learn machine learning
#
#          Video ID Published At           Keyword    Likes  Comments      Views
# ...

# %%
# Passo 5 : Nesse passo será feito no futuro a transformação de dados via pandas

# %%
# Passo 6: Exportação a pasta do Google Drive
df.to_csv('/content/drive/MyDrive/youtube/youtube_tratado.csv')

# %% [markdown]
# ## **Opcional BigQuery**

# %%
# Passo 1: Autenticando usuário no Goole Colab
from google.colab import auth
auth.authenticate_user()
print('Authenticate')
# Out:
# Authenticate

# %%
# Passo 2: Importando a biblioteca do Google BigQuery em ambiente Python
from google.cloud import bigquery
import pandas as pd
import pandas_gbq

# %%
# Passo 3: Informando o nome do projeto
project_id = 'aulabigquerysd4'
client = bigquery.Client(project=project_id)

# %%
# Passo 4: Realizando a conexão da consulta com a bigquery
#query_extracao = client.query('''SELECT * FROM `aulabigquerysd4.youtube.youtube_tratado
#''')
query_extracao = client.query('''SELECT * FROM `aulabigquerysd4.youtube.youtube_tratado` ''')

# %%
# Passo 5: Lendo os conjuntos de dados
query_extracao
# Out:
# QueryJob<project=aulabigquerysd4, location=US, id=6ae41f50-8638-44a6-a5a8-bdcd902c7958>

# %%
# Passo 6:Convertendo a nossa consulta em um DataFrame
df = query_extracao.to_dataframe()

# %%
# Passo 7: Ver o dataframe
df
# Out:
#       int64_field_0                                             titulo  \
# 0              1780  How I Would Learn Data Science in 2022 (If I C...
# 1               145  Best Of Boxing 2021 | Full Episode | SHOWTIME ...
# 2              1456                Physics Review - Basic Introduction
# 3              1730  Mistake: Forgive Only Once | Exclusive English...
# 4               313         How to Get Sturdy in 2022 | Dance Tutorial
# ...             ...                                                ...
# 1848           1710  The Magnificent Seven - Full Movie In English ...
# 1849           1441                       Physics - Basic Introduction
# 1850            348  Chappelle&#39;s Show - Wu-Tang Financial (ft. ...
# 1851            590  Top New Comedy Video Amazing Funny Video 2021 ...
# 1852           1078  Best of lofi hip hop 2021 âœ¨ - beats to relax...
#
#      data_publicacao     palavra_chave  qtd_curtidas  qtd_comentarios  \
# ...

# %%
# Passo 8: Transformação dos dados via pandas

# %%
# Passo 9: É necessário ir na bigquery  e criar uma tabela em branco e copiar o id dela

# %%
# Passo 10: Coloque o caminho da tabela do bigquery onde você carregara seus dados
table_id = 'aulabigquerysd4.youtube.youtube_tratado2'

# %%
# Passo 11: Carregando dados na Bigquery
pandas_gbq.to_gbq(df, table_id, project_id=project_id)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 578.37it/s]
