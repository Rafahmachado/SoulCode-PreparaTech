# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafahmachado/SoulCode-PreparaTech/blob/main/Aula_14_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Conectando MySQL ao Google Colab

# %%
# Instalação do pacote mysql-connector-python usando o gerenciador de pacotes pip
# !pip install mysql-connector-python

# %%
# Importação das bibliotecas necessárias
import mysql.connector # necessária para se conectar com o banco de dados MySQL
import pandas as pd # Será usada para visualização das tabelas extraídas do My SQL

# %%
# Definição das informações de conexão ao banco de dados
host = 'gcp.connect.psdb.cloud'
user = '6uv2uczi3f9vc7fltgo7'
password = 'pscale_pw_xI3UINJGd5X5Db5jkRa83wOs1vWuCx7xd8GXfctvBMC'
database = 'loja'

# %%
'''
Objetivo: Fazer uma consulta que retorne as tabelas do banco de dados loja
'''
# Estabelecimento da conexão com o banco de dados usando as informações fornecidas
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SHOW TABLES;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
tables = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(tables) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: exibe todas as tabelas do banco de dados loja
'''
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria
# '\nResumo do comando: exibe todas as tabelas do banco de dados loja\n'

# %% [markdown]
# # 2 - Fazendo as consultas ao banco MySQL via Python

# %% [markdown]
# ## 2.1 - Consultando os dados de todas as tabelas e armazenando em Pandas

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela Cliente
'''
# Estabelecimento da conexão com o banco de dados usando as informações fornecidas
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM Cliente' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
clientes = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(clientes) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: Cliente e armazena
os resultados da consulta em um dataframe Pandas chamado clientes
'''
# Out:
#     id_cliente         nome endereco
# 0            1      Douglas       SP
# 1            2      Daniela       SP
# 2            3        Ester       MG
# 3            4        Maria       BA
# 4            5      Douglas       PE
# 5            6     Raimundo       CE
# 6            7     Jucimara       GO
# 7            8      Marlene       AC
# 8            9      Douglas       MA
# 9           10      Daniela       PI
# 10          11        Pedro       PB
# 11          12      Joaquim       RS
# 12          13        Julio       TO
# 13          14        Carla       DF
# 14          15       Bianca       PA
# 15          16       Sandra       SP
# 16          17        Celso       SP
# 17          18      Silvana       BA
# 18          19  Prof Raquel       BA
# 19          20        Pedro       SP
# '\nResumo do comando: Seleciona todas as colunas da tabela: Cliente e armazena\nos resultados da consulta em um dataframe Pandas chamado clientes\n'

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela Pedido
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM Pedido;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
pedidos = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(pedidos) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: Pedido e armazena
os resultados da consulta em um dataframe Pandas chamado pedidos
'''

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela Produto
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM Produto;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
produtos = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(produtos) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: Produto e armazena
os resultados da consulta em um dataframe Pandas chamado produtos
'''

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela ItemPedido
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM ItemPedido;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
itempedido = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(itempedido) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: ItemPedido e armazena
os resultados da consulta em um dataframe Pandas chamado itempedido
'''

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela Categoria
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM Categoria;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
categoria = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(categoria) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: Categoria e armazena
os resultados da consulta em um dataframe Pandas chamado categoria
'''

# %%
'''
Objetivo: Fazer uma consulta que retorne todos os campos e todos os registros
da tabela ProdutoCategoria
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()# Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT * FROM ProdutoCategoria;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
produtocategoria = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(produtocategoria) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: ProdutoCategoria e armazena
os resultados da consulta em um dataframe Pandas chamado produtocategoria
'''
# Out:
#    id_produto  id_categoria
# 0           1             2
# 1           2             1
# 2           3             1
# 3           4             1
# 4           5             2
# '\nResumo do comando: Seleciona todas as colunas da tabela: ProdutoCategoria e armazena\nos resultados da consulta em um dataframe Pandas chamado produtocategoria\n'

# %%
'''
Dica: Evite o uso do *, seja específico, adicione apenas as colunas que irá precisar na sua análise.
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()# Criação de um cursor para executar consultas SQL no banco de dados
query = 'SELECT id_produto, quantidade FROM ItemPedido;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
id_qtde_itempedido = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(id_qtde_itempedido) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela: ItemPedido e armazena
os resultados da consulta em um dataframe Pandas chamado id_qtde_itempedido
'''
# Out:
#     id_produto  quantidade
# 0            1           2
# 1            2           5
# 2            3           7
# 3            5          10
# 4            5          11
# 5            4          30
# 6            4          32
# 7            4          44
# 8            5          13
# 9            4          33
# 10           5          34
# 11           4          32
# 12           2          33
# 13           2          34
# 14           4          27
# 15           2          18
# 16           5          17
# 17           2          33
# 18           1          50
# 19           1          47
# '\nResumo do comando: Seleciona todas as colunas da tabela: ItemPedido e armazena\nos resultados da consulta em um dataframe Pandas chamado id_qtde_itempedido\n'

# %% [markdown]
# ## 2.2 - Consultas com WHERE (Condições)

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT id_produto, quantidade FROM ItemPedido
WHERE quantidade >= 40;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
where1 = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(where1) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: id_produto e quantidade da tabela:
ItemPedido, quando a quantidade for maior ou igual a 40 e armazena
os resultados da consulta em um dataframe Pandas chamado where1
'''
# Out:
#    id_produto  quantidade
# 0           4          44
# 1           1          50
# 2           1          47
# '\nResumo do comando: Seleciona as colunas: id_produto e quantidade da tabela:\nItemPedido, quando a quantidade for maior ou igual a 40 e armazena\nos resultados da consulta em um dataframe Pandas chamado where1\n'

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''SELECT * FROM Cliente
WHERE endereco = "SP";''' #campo de texto precisa estar em aspas na consulta
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
where2 = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(where2) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona todas as colunas da tabela cliente,
quando o endereço for igual a SP e armazena os resultados da consulta em um
dataframe Pandas chamado where2
'''
# Out:
#    id_cliente     nome endereco
# 0           1  Douglas       SP
# 1           2  Daniela       SP
# 2          16   Sandra       SP
# 3          17    Celso       SP
# 4          20    Pedro       SP
# '\nResumo do comando: Seleciona todas as colunas da tabela cliente, \nquando o endereço for igual a SP e armazena os resultados da consulta em um \ndataframe Pandas chamado where2\n'

# %% [markdown]
# ## 2.3 - Consultando valores distintos - DISTINCT

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT DISTINCT id_produto, quantidade FROM ItemPedido
WHERE quantidade = 10;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona distintamente as colunas: id_produto e quantidade
da tabela: ItemPedido, quando o quando a quantidade for igual a 10.
e armazena os resultados da consulta em um dataframe Pandas chamado distinct
'''
# Out:
#    id_produto  quantidade
# 0           5          10
# '\nResumo do comando: Seleciona distintamente as colunas: id_produto e quantidade\nda tabela: ItemPedido, quando o quando a quantidade for igual a 10.\ne armazena os resultados da consulta em um dataframe Pandas chamado distinct\n'

# %% [markdown]
# ## 2.4 - Consultando registros limitados - LIMIT

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT * FROM Cliente
LIMIT 5;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
limit = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(limit) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Lendo o comando: Seleciona todos os atributos da tabela
Cliente e mostra apenas os cinco primeiros registros, e armazena os resultados
da consulta em um dataframe Pandas chamado limit
'''
# Out:
#    id_cliente     nome endereco
# 0           1  Douglas       SP
# 1           2  Daniela       SP
# 2           3    Ester       MG
# 3           4    Maria       BA
# 4           5  Douglas       PE
# '\nResumo do comando: Lendo o comando: Seleciona todos os atributos da tabela\nCliente e mostra apenas os cinco primeiros registros, e armazena os resultados\nda consulta em um dataframe Pandas chamado limit\n'

# %% [markdown]
# ## 2.5 - Usando BOOLEANOS (AND|OR|NOT)

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT nome, endereco
FROM Cliente
WHERE endereco = 'BA'
AND id_cliente = 19;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
e = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(e) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,
apenas os registros com endereco igual a 'BA' e id_cliente igual a 19, e
armazena os resultados da consulta em um dataframe Pandas chamado e
'''
# Out:
#           nome endereco
# 0  Prof Raquel       BA
# "\nResumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,\napenas os registros com endereco igual a 'BA' e id_cliente igual a 19, e\narmazena os resultados da consulta em um dataframe Pandas chamado e\n"

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT nome, endereco
FROM Cliente
WHERE endereco = 'SP'
OR endereco = 'MG';
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
ou = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(ou) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,
apenas os registros com endereco igual a 'SP' ou endereco a 'MG', e
armazena os resultados da consulta em um dataframe Pandas chamado ou
'''
# Out:
#       nome endereco
# 0  Douglas       SP
# 1  Daniela       SP
# 2    Ester       MG
# 3   Sandra       SP
# 4    Celso       SP
# 5    Pedro       SP
# "\nResumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,\napenas os registros com endereco igual a 'SP' ou endereco a 'MG', e\narmazena os resultados da consulta em um dataframe Pandas chamado ou\n"

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT nome, endereco
FROM Cliente
WHERE NOT endereco = 'SP';
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
nao = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(nao) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,
apenas os registros com endereco não seja igual a 'SP', e armazena os resultados
da consulta em um dataframe Pandas chamado nao
'''
# Out:
#            nome endereco
# 0         Ester       MG
# 1         Maria       BA
# 2       Douglas       PE
# 3      Raimundo       CE
# 4      Jucimara       GO
# 5       Marlene       AC
# 6       Douglas       MA
# 7       Daniela       PI
# 8         Pedro       PB
# 9       Joaquim       RS
# 10        Julio       TO
# 11        Carla       DF
# 12       Bianca       PA
# 13      Silvana       BA
# 14  Prof Raquel       BA
# "\nResumo do comando: Seleciona as colunas: nome e endereco da tabela: Clientes,\napenas os registros com endereco não seja igual a 'SP', e armazena os resultados\nda consulta em um dataframe Pandas chamado nao\n"

# %% [markdown]
# ## 2.6 - Funções de agregação ( SUM , AVG , MAX , MIN, COUNT e ROUND )

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT SUM(quantidade) AS soma_qtde
FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
soma = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(soma) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: quantidade da tabela ItemPedido,
retorna o somatório da coluna, e armazena os resultados da consulta em um
dataframe Pandas chamado soma
'''
# Out:
#   soma_qtde
# 0       512
# '\nResumo do comando: Seleciona as colunas: quantidade da tabela ItemPedido,\nretorna o somatório da coluna, e armazena os resultados da consulta em um\ndataframe Pandas chamado soma\n'

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT AVG(quantidade) AS media_qtde,
round(AVG(quantidade),2) AS media_qtde_arredondado
FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
media = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(media) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona as colunas: quantidade da tabela ItemPedido,
retorna o valor arredondado (ROUND) médio da coluna (AVG), e armazena os
resultados da consulta em um dataframe Pandas chamado media
'''
# Out:
#   media_qtde media_qtde_arredondado
# 0    25.6000                  25.60
# '\nResumo do comando: Seleciona as colunas: quantidade da tabela ItemPedido,\nretorna o valor arredondado (ROUND) médio da coluna (AVG), e armazena os\nresultados da consulta em um dataframe Pandas chamado media\n'

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT MAX(quantidade) AS maior_quantidade_venda
  FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
max = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(max) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Maior quantidade de produtos vendidos da tabela:ItemPedido,
e armazena os resultados da consulta em um dataframe Pandas chamado max
'''
# Out:
#    maior_quantidade_venda
# 0                      50
# '\nResumo do comando: Maior quantidade de produtos vendidos da tabela:ItemPedido,\ne armazena os resultados da consulta em um dataframe Pandas chamado max\n'

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT MIN(quantidade)  menor_quantidade_venda
  FROM ItemPedido;
''' # nesse faltou a palavra reserva AS, mesmo assim o MySQL entende e realiza a consulta
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
min = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(min) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando:Seleciona a menor quantidade de produtos vendidos da
tabela:ItemPedido, e armazena os resultados da consulta em um dataframe
Pandas chamado min
'''
# Out:
#    menor_quantidade_venda
# 0                       2
# '\nResumo do comando:Seleciona a menor quantidade de produtos vendidos da\ntabela:ItemPedido, e armazena os resultados da consulta em um dataframe\nPandas chamado min\n'

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT count(id_produto) as qtd_produtos
  FROM Produto;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
contagem = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(contagem) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Seleciona a coluna ide_produto e faz a contagem de itens a
partir da tabela:Produto, e armazena os resultados da consulta em um dataframe
Pandas chamado contagem
'''
# Out:
#    qtd_produtos
# 0             5
# '\nResumo do comando: Seleciona a coluna ide_produto e faz a contagem de itens a\npartir da tabela:Produto, e armazena os resultados da consulta em um dataframe\nPandas chamado contagem\n'

# %% [markdown]
# # 3 - SQL para análise de dados

# %% [markdown]
# ## 3.1 - GROUP BY

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT endereco
     , count(*) as freq
  FROM Cliente
 GROUP BY endereco;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
grupo = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(grupo) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Comando que seleciona o atributo endereço, cria e seleciona a
coluna count renomeada com freq da tabela Cliente e agrupa por endereco,
e armazena os resultados da consulta em um dataframe Pandas chamado grupo
'''
# Out:
#    endereco  freq
# 0        SP     5
# 1        MG     1
# 2        BA     3
# 3        PE     1
# 4        CE     1
# 5        GO     1
# 6        AC     1
# 7        MA     1
# 8        PI     1
# 9        PB     1
# 10       RS     1
# 11       TO     1
# 12       DF     1
# 13       PA     1
# '\nResumo do comando: Comando que seleciona o atributo endereço, cria e seleciona a\ncoluna count renomeada com freq da tabela Cliente e agrupa por endereco,\ne armazena os resultados da consulta em um dataframe Pandas chamado grupo\n'

# %% [markdown]
# ## 3.2 - Agrupamento Condicional - HAVING

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT endereco
     , count(*)
  FROM Cliente
 GROUP BY endereco
 HAVING count(*) > 1;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
tendo = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(tendo) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Consulta que seleciona endereco e contangem de endereco da
tabela Cliente, Agrupado por endereço tendo apenas (HAVING) os edereços que se
repetem pelo menos duas vezes. e armazena os resultados da consulta
em um dataframe Pandas chamado tendo
'''
# Out:
#   endereco  count(*)
# 0       SP         5
# 1       BA         3
# '\nResumo do comando: Consulta que seleciona endereco e contangem de endereco da\ntabela Cliente, Agrupado por endereço tendo apenas (HAVING) os edereços que se\nrepetem pelo menos duas vezes. e armazena os resultados da consulta\nem um dataframe Pandas chamado tendo\n'

# %% [markdown]
# ## 3.3 - Combinando os resultados de duas consultas - UNION

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT id_pedido, id_produto
  FROM ItemPedido
 WHERE id_produto = 2
UNION
SELECT id_pedido, id_produto
  FROM ItemPedido
 WHERE id_produto = 3;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
uniao = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(uniao) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: Unindo duas consultas, sendo a primeira como a seleção de
id_pedido e id_produto da tabela ItemPedido onde o id_produto é 1, e a segunda
como a seleção de id_pedido e id_produto da tabela ItemPedido onde o
id_produto é 4 e armazena os resultados da consulta
em um dataframe Pandas chamado uniao
'''
# Out:
#    id_pedido  id_produto
# 0          2           2
# 1         13           2
# 2         14           2
# 3         16           2
# 4         18           2
# 5          3           3
# '\nResumo do comando: Unindo duas consultas, sendo a primeira como a seleção de\nid_pedido e id_produto da tabela ItemPedido onde o id_produto é 1, e a segunda\ncomo a seleção de id_pedido e id_produto da tabela ItemPedido onde o\nid_produto é 4 e armazena os resultados da consulta\nem um dataframe Pandas chamado uniao\n'

# %% [markdown]
# ## 3.4 - IN e BEETWEEN

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT
    id_pedido,
    id_produto
  FROM ItemPedido
 WHERE id_produto IN (1, 2)
   AND id_pedido BETWEEN 1 AND 9;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#    id_pedido  id_produto
# 0          1           1
# 1          2           2

# %% [markdown]
# ## 3.5 - LIKE

# %%
'''
Agora vamos para a tabela Produto e no atributo nome vamos realizar uma consulta
que nos retorne todos os produtos que terminem com a letra o e os seus
respectivos ids
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT
  id_produto,
  nome
  FROM Produto
  WHERE nome LIKE '%o';
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#    id_produto   nome
# 0           2  Garfo
# 1           5   Copo

# %%
'''
Agora vamos para a tabela Produto e no atributo nome vamos realizar uma consulta
que nos retorne todos os produtos que comecem com a letra C e os seus
respectivos ids
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT
  id_produto,
  nome
  FROM Produto
  WHERE nome LIKE 'C%';
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
like = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(like) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#    id_produto    nome
# 0           1  Caneca
# 1           4  Colher
# 2           5    Copo

# %%
'''
Agora vamos para a tabela Produto e no atributo nome vamos realizar uma consulta
que nos retorne todos os produtos que contenha a sequencia lh e os seus
respectivos ids
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT
  id_produto,
  nome
  FROM Produto
  WHERE nome LIKE '%lh%';
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
contem = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(contem) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#    id_produto    nome
# 0           4  Colher

# %% [markdown]
# ## 3.6 - NULL e NOT NULL

# %%
'''
Verficar a existência de valores nulos para o atributo nome na tabela Produto
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
Select nome from Produto
WHERE nome IS NULL;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
# Empty DataFrame
# Columns: [nome]
# Index: []

# %%
'''
Verficar a existência de valores não nulos para o atributo
nome na tabela Produto
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
Select nome from Produto
WHERE nome IS NOT NULL;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#      nome
# 0  Caneca
# 1   Garfo
# 2    Faca
# 3  Colher
# 4    Copo

# %% [markdown]
# ## 3.7 ORDER BY

# %%
'''
Vamos selecionar todos os atributos da tabela ItemPedido, ordenando de forma
Crescente por quantidade
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM ItemPedido
 ORDER BY quantidade ASC;
''' # se não usarmos asc ou desc, por padrão ele usará asc
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0         1          1           1           2
# 1         2          2           2           5
# 2         3          3           3           7
# 3         4          4           5          10
# 4         5          5           5          11
# 5         9          9           5          13
# 6        17         17           5          17
# 7        16         16           2          18
# 8        15         15           4          27
# 9         6          6           4          30
# 10        7          7           4          32
# 11       12         12           4          32
# 12       18         18           2          33
# 13       10         10           4          33
# 14       13         13           2          33
# 15       11         11           5          34
# 16       14         14           2          34
# 17        8          8           4          44
# 18       20         20           1          47
# 19       19         19           1          50

# %%
'''
Vamos selecionar todos os atributos da tabela ItemPedido, ordenando de forma
decrescente por quantidade
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM ItemPedido
 ORDER BY quantidade DESC;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0        19         19           1          50
# 1        20         20           1          47
# 2         8          8           4          44
# 3        11         11           5          34
# 4        14         14           2          34
# 5        10         10           4          33
# 6        13         13           2          33
# 7        18         18           2          33
# 8         7          7           4          32
# 9        12         12           4          32
# 10        6          6           4          30
# 11       15         15           4          27
# 12       16         16           2          18
# 13       17         17           5          17
# 14        9          9           5          13
# 15        5          5           5          11
# 16        4          4           5          10
# 17        3          3           3           7
# 18        2          2           2           5
# 19        1          1           1           2

# %% [markdown]
# ## 3.8 - Tratamento de texto
# TRIM, REPLACE, LPAD, REPLICATE, SUBSTRING, UPPER, LOWER e LEN

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT nome, id_produto,
       TRIM(nome) AS trim,
       REPLACE(nome, 'o', 'oo') AS rep,
       LPAD(id_produto, 5, "0") AS lpad,
       SUBSTRING(nome, 1, 2) AS sub,
       UPPER(nome) AS UPPER,
       LOWER(nome) AS LOWER,
       LENGTH(nome) AS LENGTH
  FROM Produto AS prod;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
TRIM— remove espaços
REPLACE— substitui algo por algo
LPAD e REPLICATE— Replica valores
SUBSTRING— pega trecho de um texto
UPPER— deixa tudo maiúsculo
LOWER— deixa tudo minúsculo
LENGTH— calcula a quantidade de caracteres
'''
# Out:
#      nome  id_produto    trim      rep   lpad sub   UPPER   LOWER  LENGTH
# 0  Caneca           1  Caneca   Caneca  00001  Ca  CANECA  caneca       6
# 1   Garfo           2   Garfo   Garfoo  00002  Ga   GARFO   garfo       5
# 2    Faca           3    Faca     Faca  00003  Fa    FACA    faca       4
# 3  Colher           4  Colher  Coolher  00004  Co  COLHER  colher       6
# 4    Copo           5    Copo   Coopoo  00005  Co    COPO    copo       4
# '\nTRIM— remove espaços\nREPLACE— substitui algo por algo\nLPAD e REPLICATE— Replica valores\nSUBSTRING— pega trecho de um texto\nUPPER— deixa tudo maiúsculo\nLOWER— deixa tudo minúsculo\nLENGTH— calcula a quantidade de caracteres\n'

# %% [markdown]
# ## 3.9 - Conversão de tipos - CAST

# %%
'''
Nesse bloco vamos selecionar o atributo id_cliente da tabela pedido e vamos
fazer uma consulta que retorne uma coluna nova chamada id_cliente_texto com
a concatenação (CONCAT) do texto "Cliente - " com o id do cliente
convertido (CAST) em texto
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT id_cliente,
       concat('Cliente - ', CAST(id_cliente AS CHAR)) AS id_cliente_texto
  FROM Pedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_cliente id_cliente_texto
# 0            1      Cliente - 1
# 1            1      Cliente - 1
# 2            2      Cliente - 2
# 3            5      Cliente - 5
# 4           19     Cliente - 19
# 5           19     Cliente - 19
# 6           15     Cliente - 15
# 7            8      Cliente - 8
# 8            2      Cliente - 2
# 9           19     Cliente - 19
# 10           6      Cliente - 6
# 11          11     Cliente - 11
# 12          10     Cliente - 10
# 13           4      Cliente - 4
# 14           3      Cliente - 3
# 15           3      Cliente - 3
# 16           2      Cliente - 2
# 17          17     Cliente - 17
# 18          14     Cliente - 14
# 19          13     Cliente - 13

# %% [markdown]
# ## 3.10 - CASE WHEN - Semelhante ao IF/ELSE

# %%
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT id_pedido,
	CASE WHEN quantidade > 30 THEN 'Atacado'
    ELSE 'Varejo' END
FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_pedido case when quantidade > 30 then 'Atacado' else 'Varejo' end
# 0           1                                             Varejo
# 1           2                                             Varejo
# 2           3                                             Varejo
# 3           4                                             Varejo
# 4           5                                             Varejo
# 5           6                                             Varejo
# 6           7                                            Atacado
# 7           8                                            Atacado
# 8           9                                             Varejo
# 9          10                                            Atacado
# 10         11                                            Atacado
# 11         12                                            Atacado
# 12         13                                            Atacado
# 13         14                                            Atacado
# 14         15                                             Varejo
# 15         16                                             Varejo
# 16         17                                             Varejo
# 17         18                                            Atacado
# 18         19                                            Atacado
# 19         20                                            Atacado

# %% [markdown]
# ## 3.11 - Armazenando uma consulta - VIEW

# %%
'''
Agora vamos construir a mesma consulta executada no bloco anteior, porém, essa
consulta será uma VIEW, isso significa que essa consulta ficará guardada no
banco de dados original, no entanto não ocupará o espaço de uma tabela orginal
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
CREATE OR REPLACE VIEW query_class as
SELECT id_pedido,
	CASE WHEN quantidade > 30 THEN 'Atacado'
    ELSE 'Varejo' END
FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
'''
Objetivo: Fazer uma consulta que retorne as tabelas do banco de dados loja
'''
# Estabelecimento da conexão com o banco de dados usando as informações fornecidas
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SHOW TABLES;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
tables = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(tables) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: exibe todas as tabelas do banco de dados
aqui podemos perceber que a view criada no bloco anterior está armazenada
no banco de dados original como uma tabela chamada query_class
'''
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria
# 6       query_class
# '\nResumo do comando: exibe todas as tabelas do banco de dados\naqui podemos perceber que a view criada no bloco anterior está armazenada\nno banco de dados original como uma tabela chamada query_class\n'

# %%
# Leitura da VIEW
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
select * from query_class;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Esse bloco faz a leitura da consulta que está armazenada no banco original
'''
# Out:
#     id_pedido case when quantidade > 30 then 'Atacado' else 'Varejo' end
# 0           1                                             Varejo
# 1           2                                             Varejo
# 2           3                                             Varejo
# 3           4                                             Varejo
# 4           5                                             Varejo
# 5           6                                             Varejo
# 6           7                                            Atacado
# 7           8                                            Atacado
# 8           9                                             Varejo
# 9          10                                            Atacado
# 10         11                                            Atacado
# 11         12                                            Atacado
# 12         13                                            Atacado
# 13         14                                            Atacado
# 14         15                                             Varejo
# 15         16                                             Varejo
# 16         17                                             Varejo
# 17         18                                            Atacado
# 18         19                                            Atacado
# 19         20                                            Atacado
# '\nEsse bloco faz a leitura da consulta que está armazenada no banco original\n'

# %%
'''
Nesse bloco faremos a exclusão da VIEW do banco original e o mesmo voltará a ter
as 6 tabelas iniciais
'''
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'DROP VIEW query_class;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta

# %%
'''
Objetivo: Fazer uma consulta que retorne as tabelas do banco de dados loja
'''
# Estabelecimento da conexão com o banco de dados usando as informações fornecidas
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor() # Criação de um cursor para executar consultas SQL no banco de dados
query = 'SHOW TABLES;' # Definição da consulta SQL a ser executada
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
tables = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(tables) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
'''
Resumo do comando: exibe todas as tabelas do banco de dados
'''
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria
# '\nResumo do comando: exibe todas as tabelas do banco de dados\n'

# %% [markdown]
# # 4 - JOINS

# %% [markdown]
# ## 4.0 - ESQUEMA GERAL
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.1 LEFT JOIN

# %%
'''
-- O Left Join tem como resultado todos os registros que estão na tabela
A (mesmo que não estejam na tabela B)
-- e os registros da tabela B que são comuns à tabela A.
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM      Cliente c
  LEFT JOIN Pedido p ON p.id_cliente = c.id_cliente;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_cliente         nome endereco  id_pedido  id_cliente descricao
# 0            1      Douglas       SP        2.0         1.0     Garfo
# 1            1      Douglas       SP        1.0         1.0    Caneca
# 2            2      Daniela       SP       17.0         2.0      Copo
# 3            2      Daniela       SP        9.0         2.0      Copo
# 4            2      Daniela       SP        3.0         2.0      Faca
# 5            3        Ester       MG       16.0         3.0     Garfo
# 6            3        Ester       MG       15.0         3.0    Colher
# 7            4        Maria       BA       14.0         4.0     Garfo
# 8            5      Douglas       PE        4.0         5.0      Copo
# 9            6     Raimundo       CE       11.0         6.0      Copo
# 10           7     Jucimara       GO        NaN         NaN      None
# 11           8      Marlene       AC        8.0         8.0    Colher
# 12           9      Douglas       MA        NaN         NaN      None
# 13          10      Daniela       PI       13.0        10.0     Garfo
# 14          11        Pedro       PB       12.0        11.0    Colher
# 15          12      Joaquim       RS        NaN         NaN      None
# 16          13        Julio       TO       20.0        13.0    Caneca
# 17          14        Carla       DF       19.0        14.0    Caneca
# 18          15       Bianca       PA        7.0        15.0    Colher
# 19          16       Sandra       SP        NaN         NaN      None
# 20          17        Celso       SP       18.0        17.0     Garfo
# 21          18      Silvana       BA        NaN         NaN      None
# 22          19  Prof Raquel       BA       10.0        19.0    Colher
# 23          19  Prof Raquel       BA        6.0        19.0    Colher
# 24          19  Prof Raquel       BA        5.0        19.0      Copo
# 25          20        Pedro       SP        NaN         NaN      None

# %% [markdown]
# ## 4.2 - INNER JOIN

# %%
'''
-- -------------
-- Inner Join --
-- -------------
-- O Inner Join é o método de junção mais conhecido e retorna os registros que
são comuns às duas tabelas.
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM  ItemPedido vendas
  INNER JOIN ProdutoCategoria cat ON cat.id_produto = vendas.id_produto;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_item  id_pedido  id_produto  quantidade  id_produto  id_categoria
# 0         1          1           1           2           1             2
# 1         2          2           2           5           2             1
# 2         3          3           3           7           3             1
# 3         4          4           5          10           5             2
# 4         5          5           5          11           5             2
# 5         6          6           4          30           4             1
# 6         7          7           4          32           4             1
# 7         8          8           4          44           4             1
# 8         9          9           5          13           5             2
# 9        10         10           4          33           4             1
# 10       11         11           5          34           5             2
# 11       12         12           4          32           4             1
# 12       13         13           2          33           2             1
# 13       14         14           2          34           2             1
# 14       15         15           4          27           4             1
# 15       16         16           2          18           2             1
# 16       17         17           5          17           5             2
# 17       18         18           2          33           2             1
# 18       19         19           1          50           1             2
# 19       20         20           1          47           1             2

# %% [markdown]
# ## 4.3 - RIGHT JOIN

# %%
'''
-- -------------
-- Right Join --
-- -------------
-- Usando o Right Join teremos como resultado todos os registros que estão
na tabela B (mesmo que não estejam na tabela A)  e os registros da tabela A
que são comuns à tabela B.
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM      Pedido p
  RIGHT JOIN Cliente c ON p.id_cliente = c.id_cliente;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#     id_pedido  id_cliente descricao  id_cliente         nome endereco
# 0         2.0         1.0     Garfo           1      Douglas       SP
# 1         1.0         1.0    Caneca           1      Douglas       SP
# 2        17.0         2.0      Copo           2      Daniela       SP
# 3         9.0         2.0      Copo           2      Daniela       SP
# 4         3.0         2.0      Faca           2      Daniela       SP
# 5        16.0         3.0     Garfo           3        Ester       MG
# 6        15.0         3.0    Colher           3        Ester       MG
# 7        14.0         4.0     Garfo           4        Maria       BA
# 8         4.0         5.0      Copo           5      Douglas       PE
# 9        11.0         6.0      Copo           6     Raimundo       CE
# 10        NaN         NaN      None           7     Jucimara       GO
# 11        8.0         8.0    Colher           8      Marlene       AC
# 12        NaN         NaN      None           9      Douglas       MA
# 13       13.0        10.0     Garfo          10      Daniela       PI
# 14       12.0        11.0    Colher          11        Pedro       PB
# 15        NaN         NaN      None          12      Joaquim       RS
# 16       20.0        13.0    Caneca          13        Julio       TO
# 17       19.0        14.0    Caneca          14        Carla       DF
# 18        7.0        15.0    Colher          15       Bianca       PA
# 19        NaN         NaN      None          16       Sandra       SP
# 20       18.0        17.0     Garfo          17        Celso       SP
# 21        NaN         NaN      None          18      Silvana       BA
# 22       10.0        19.0    Colher          19  Prof Raquel       BA
# 23        6.0        19.0    Colher          19  Prof Raquel       BA
# 24        5.0        19.0      Copo          19  Prof Raquel       BA
# 25        NaN         NaN      None          20        Pedro       SP

# %% [markdown]
# ## 4.4 - OUTER JOIN

# %%
'''
-- -------------
-- Outer Join --
-- -------------
-- O Outer Join (também conhecido por Full Outer Join ou Full Join) tem como
resultado todos os registros que estão na tabela A e todos os registros da tabela B.
-- No MySQL não tem nativamente
'''
# Abertura da conexão para uma nova consulta
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()  # Criação de um cursor para executar consultas SQL no banco de dados
# Definição da consulta SQL a ser executada
query = '''
SELECT *
  FROM      Cliente c
  LEFT JOIN Pedido p ON p.id_cliente = c.id_cliente
UNION
SELECT *
  FROM      Pedido p
  LEFT JOIN Cliente c ON p.id_cliente = c.id_cliente;
'''
cursor.execute(query) # Execução da consulta no banco de dados
result = cursor.fetchall() # Recuperação de todos os resultados da consulta
distinct = pd.DataFrame(result, columns=cursor.column_names) # Criação de um DataFrame Pandas usando os resultados da consulta e os nomes das colunas do cursor
display(distinct) # Exibição do DataFrame Pandas contendo os resultados da consulta
cursor.close() # Fechamento do cursor após a conclusão da consulta
connection.close() # Fechamento da conexão após a consulta
# Out:
#    id_cliente         nome endereco  id_pedido   id_cliente descricao
# 0           1      Douglas       SP        2.0            1     Garfo
# 1           1      Douglas       SP        1.0            1    Caneca
# 2           2      Daniela       SP       17.0            2      Copo
# 3           2      Daniela       SP        9.0            2      Copo
# 4           2      Daniela       SP        3.0            2      Faca
# 5           3        Ester       MG       16.0            3     Garfo
# 6           3        Ester       MG       15.0            3    Colher
# 7           4        Maria       BA       14.0            4     Garfo
# 8           5      Douglas       PE        4.0            5      Copo
# 9           6     Raimundo       CE       11.0            6      Copo
# 10          7     Jucimara       GO        NaN         None      None
# 11          8      Marlene       AC        8.0            8    Colher
# 12          9      Douglas       MA        NaN         None      None
# 13         10      Daniela       PI       13.0           10     Garfo
# 14         11        Pedro       PB       12.0           11    Colher
# 15         12      Joaquim       RS        NaN         None      None
# 16         13        Julio       TO       20.0           13    Caneca
# 17         14        Carla       DF       19.0           14    Caneca
# 18         15       Bianca       PA        7.0           15    Colher
# 19         16       Sandra       SP        NaN         None      None
# 20         17        Celso       SP       18.0           17     Garfo
# 21         18      Silvana       BA        NaN         None      None
# 22         19  Prof Raquel       BA       10.0           19    Colher
# 23         19  Prof Raquel       BA        6.0           19    Colher
# 24         19  Prof Raquel       BA        5.0           19      Copo
# 25         20        Pedro       SP        NaN         None      None
# 26          1            1   Caneca        1.0      Douglas        SP
# 27          2            1    Garfo        1.0      Douglas        SP
# 28          3            2     Faca        2.0      Daniela        SP
# 29          4            5     Copo        5.0      Douglas        PE
# 30          5           19     Copo       19.0  Prof Raquel        BA
# 31          6           19   Colher       19.0  Prof Raquel        BA
# 32          7           15   Colher       15.0       Bianca        PA
# 33          8            8   Colher        8.0      Marlene        AC
# 34          9            2     Copo        2.0      Daniela        SP
# 35         10           19   Colher       19.0  Prof Raquel        BA
# 36         11            6     Copo        6.0     Raimundo        CE
# 37         12           11   Colher       11.0        Pedro        PB
# 38         13           10    Garfo       10.0      Daniela        PI
# 39         14            4    Garfo        4.0        Maria        BA
# 40         15            3   Colher        3.0        Ester        MG
# 41         16            3    Garfo        3.0        Ester        MG
# 42         17            2     Copo        2.0      Daniela        SP
# 43         18           17    Garfo       17.0        Celso        SP
# 44         19           14   Caneca       14.0        Carla        DF
# 45         20           13   Caneca       13.0        Julio        TO
